# %% [markdown]
# <div style="text-align: center;">
#   <img width="420" height="420" src="https://www.naterscreations.com/imputegap/logo_imputegab.png" />
# </div>
#
# <h1>ImputeGAP: Explore Notebook</h1>

# %%
# %pip install imputegap
# %pip install -U ipywidgets

# %% [markdown]
# <h1>Benchmark</h1>

# %% [markdown]
# ImputeGAP can serve as a common test-bed for comparing the effectiveness and efficiency of time series imputation algorithms. Users have full control over the benchmark by customizing various parameters, including the list of the algorithms to compare, the choice of optimizer to fine-tune the algorithms, the datasets to evaluate, the missingness patterns, the range of missing values, and the performance metrics.
#
# The benchmarking module can be utilized as follows:

# %%
from imputegap.recovery.benchmark import Benchmark

my_algorithms = ["SoftImpute", "KNNImpute"]

my_opt = ["default_params"]

my_datasets = ["eeg-alcohol"]

my_patterns = ["mcar"]

range = [0.05, 0.1, 0.2, 0.4, 0.6, 0.8]

my_metrics = ["*"]

# launch the evaluation
list_results, sum_scores = Benchmark().eval(algorithms=my_algorithms, datasets=my_datasets, patterns=my_patterns, x_axis=range, metrics=my_metrics, optimizers=my_opt)
# Out:
# (SYS) The time series have been loaded from /tmp/pycharm_project_615/imputegap/dataset/eeg-alcohol.txt
#
# pattern : mcar, algorithm SoftImpute, started at 2025-04-03 15:45:19.
# done!
#
#
# pattern : mcar, algorithm KNNImpute, started at 2025-04-03 15:45:20.
# done!
#
#
# the results of the analysis has been saved in :  ./imputegap_assets/benchmark
#
#
# > logs: benchmark - Execution Time: 4.6457 seconds
#
#
# Dataset: eegalcohol, pattern: mcar, metric: RMSE, parms=default_params
#
#  Rate       KNNImpute           SoftImpute
#
#  0.05      0.2410259540        0.4359915238
#   0.1      0.2889085181        0.3665001858
#   0.2      0.3252384253        0.3983300622
#   0.4      0.3382458476        0.4355910162
#   0.6      0.3656435952        0.4500113662
#   0.8      0.4985193265        0.4655442240
#
#
#
# Dataset: eegalcohol, pattern: mcar, metric: runtime_linear_scale, parms=default_params
#
#  Rate       KNNImpute           SoftImpute
#
#  0.05      0.2473430634        0.0275871754
#   0.1      0.0145347118        0.0613472462
#   0.2      0.0136024952        0.0464453697
#   0.4      0.0330574512        0.0489850044
#   0.6      0.0700719357        0.0378742218
#   0.8      0.1092321873        0.0388281345
#
#
#
# results saved in the following directory : ./imputegap_assets/benchmark/eegalcohol/mcar/report_mcar_eegalcohol.txt
#
# plots saved in the following directory :  ./imputegap_assets/benchmark/eegalcohol

# %% [raw]
# You can enable the optimizer using the following command:

# %%
opt = {"optimizer": "ray_tune", "options": {"n_calls": 1, "max_concurrent_trials": 1}}
my_opt = [opt]

# %% [markdown]
# <h1>Downstream</h1>

# %% [markdown]
# ImputeGAP includes a dedicated module for systematically evaluating the impact of data imputation on downstream tasks. Currently, forecasting is the primary supported task, with plans to expand to additional tasks in the future.

# %%
from imputegap.recovery.imputation import Imputation
from imputegap.recovery.manager import TimeSeries
from imputegap.tools import utils

# initialize the time series object
ts = TimeSeries()

# load and normalize the timeseries
ts.load_series(utils.search_path("forecast-economy"))
ts.normalize()

# contaminate the time series
ts_m = ts.Contamination.aligned(ts.data, rate_series=0.8)

# define and impute the contaminated series
imputer = Imputation.MatrixCompletion.CDRec(ts_m)
imputer.impute()

# compute and print the downstream results
downstream_config = {"task": "forecast", "model": "hw-add", "comparator": "ZeroImpute"}
imputer.score(ts.data, imputer.recov_data, downstream=downstream_config)
ts.print_results(imputer.downstream_metrics, algorithm=imputer.algorithm)
# Out:
# (SYS) The time series have been loaded from /tmp/pycharm_project_615/imputegap/dataset/forecast-economy.txt
#
# > logs: normalization (z_score) of the data - runtime: 0.0004 seconds
#
# (CONT) missigness pattern: ALIGNED
# 	rate series impacted: 20.0%
# 	missing rate per series: 80.0%
# 	starting position: 93
# 	index impacted : 93 -> 837
#
# (IMPUTATION) CDRec: (16,931) for rank 3, epsilon 1e-06, and iterations 100.
# > logs: imputation cdrec - Execution Time: 0.7270 seconds.
#
# (DOWNSTREAM) Default parameters of the downstream model loaded.
#
# (DOWNSTREAM) Analysis launched !
# task: forecast
# model: hw-add
# params: {'sp': 7, 'trend': 'add', 'seasonal': 'additive'}
# imputation algorithm: cdrec
# comparator: ZeroImpute
#
#
# plots saved in  ./imputegap_assets/downstream/25_04_03_15_47_05_forecast_hw-add_downstream.jpg
#
# Results of the analysis (cdrec) :
# MSE_original         = 0.5663304997036217
# MSE_CDREC            = 0.8353031889744237
# MSE_ZEROIMPUTE       = 0.6242557383168621
# sMAPE_original       = 89.37515160605443
# sMAPE_CDREC          = 96.53738169346516
# sMAPE_ZEROIMPUTE     = 120.24907338662449

# %% [markdown]
# All downstream models develboped in ImputeGAP are available in the **ts.forecasting_models** module, which can be listed as follows:

# %%
ts.forecasting_models
# Out:
# ['arima',
#  'bats',
#  'croston',
#  'deepar',
#  'ets',
#  'exp-smoothing',
#  'hw-add',
#  'lightgbm',
#  'lstm',
#  'naive',
#  'nbeats',
#  'prophet',
#  'sf-arima',
#  'theta',
#  'transformer',
#  'unobs',
#  'xgboost']

# %% [markdown]
# <h1>Explainer</h1>

# %% [markdown]
# The library provides insights into the algorithm’s behavior by identifying the features that impact the most the imputation results. It trains a regression model to predict imputation results across various methods and uses SHapley Additive exPlanations (SHAP) to reveal how different time series features influence the model’s predictions.
#
# Let’s illustrate the explainer using the CDRec algorithm and MCAR missingness pattern:

# %%
from imputegap.recovery.manager import TimeSeries
from imputegap.recovery.explainer import Explainer
from imputegap.tools import utils

# initialize the time series object
ts = TimeSeries()

# load and normalize the timeseries
ts.load_series(utils.search_path("eeg-alcohol"))
ts.normalize(normalizer="z_score")

# configure the explanation
shap_values, shap_details = Explainer.shap_explainer(input_data=ts.data, extractor="pycatch", pattern="mcar", file_name=ts.name, algorithm="CDRec")

# print the impact of each feature
Explainer.print(shap_values, shap_details)
# Out:
# (SYS) The time series have been loaded from /tmp/pycharm_project_615/imputegap/dataset/eeg-alcohol.txt
#
# > logs: normalization (z_score) of the data - runtime: 0.0009 seconds
#
# explainer launched
# 	extractor: pycatch
# 	imputation algorithm: CDRec
# 	params: None
# 	missigness pattern: mcar
# 	missing rate: 40.0%
# 	nbr of series training set: 38
# 	nbr of series testing set: 26
#
#
# Generation  0 / 64 ( 0 %)________________________________________________________
# 	Contamination  0 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  0 ...
#
#
# Generation  1 / 64 ( 1 %)________________________________________________________
# 	Contamination  1 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  1 ...
#
#
# Generation  2 / 64 ( 3 %)________________________________________________________
# 	Contamination  2 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  2 ...
#
#
# Generation  3 / 64 ( 4 %)________________________________________________________
# 	Contamination  3 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  3 ...
#
#
# Generation  4 / 64 ( 6 %)________________________________________________________
# 	Contamination  4 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  4 ...
#
#
# Generation  5 / 64 ( 7 %)________________________________________________________
# 	Contamination  5 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  5 ...
#
#
# Generation  6 / 64 ( 9 %)________________________________________________________
# 	Contamination  6 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  6 ...
#
#
# Generation  7 / 64 ( 10 %)________________________________________________________
# 	Contamination  7 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  7 ...
#
#
# Generation  8 / 64 ( 12 %)________________________________________________________
# 	Contamination  8 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  8 ...
#
#
# Generation  9 / 64 ( 14 %)________________________________________________________
# 	Contamination  9 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  9 ...
#
#
# Generation  10 / 64 ( 15 %)________________________________________________________
# 	Contamination  10 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  10 ...
#
#
# Generation  11 / 64 ( 17 %)________________________________________________________
# 	Contamination  11 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  11 ...
#
#
# Generation  12 / 64 ( 18 %)________________________________________________________
# 	Contamination  12 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  12 ...
#
#
# Generation  13 / 64 ( 20 %)________________________________________________________
# 	Contamination  13 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  13 ...
#
#
# Generation  14 / 64 ( 21 %)________________________________________________________
# 	Contamination  14 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  14 ...
#
#
# Generation  15 / 64 ( 23 %)________________________________________________________
# 	Contamination  15 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  15 ...
#
#
# Generation  16 / 64 ( 25 %)________________________________________________________
# 	Contamination  16 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  16 ...
#
#
# Generation  17 / 64 ( 26 %)________________________________________________________
# 	Contamination  17 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  17 ...
#
#
# Generation  18 / 64 ( 28 %)________________________________________________________
# 	Contamination  18 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  18 ...
#
#
# Generation  19 / 64 ( 29 %)________________________________________________________
# 	Contamination  19 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  19 ...
#
#
# Generation  20 / 64 ( 31 %)________________________________________________________
# 	Contamination  20 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  20 ...
#
#
# Generation  21 / 64 ( 32 %)________________________________________________________
# 	Contamination  21 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  21 ...
#
#
# Generation  22 / 64 ( 34 %)________________________________________________________
# 	Contamination  22 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  22 ...
#
#
# Generation  23 / 64 ( 35 %)________________________________________________________
# 	Contamination  23 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  23 ...
#
#
# Generation  24 / 64 ( 37 %)________________________________________________________
# 	Contamination  24 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  24 ...
#
#
# Generation  25 / 64 ( 39 %)________________________________________________________
# 	Contamination  25 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  25 ...
#
#
# Generation  26 / 64 ( 40 %)________________________________________________________
# 	Contamination  26 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  26 ...
#
#
# Generation  27 / 64 ( 42 %)________________________________________________________
# 	Contamination  27 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  27 ...
#
#
# Generation  28 / 64 ( 43 %)________________________________________________________
# 	Contamination  28 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  28 ...
#
#
# Generation  29 / 64 ( 45 %)________________________________________________________
# 	Contamination  29 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  29 ...
#
#
# Generation  30 / 64 ( 46 %)________________________________________________________
# 	Contamination  30 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  30 ...
#
#
# Generation  31 / 64 ( 48 %)________________________________________________________
# 	Contamination  31 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  31 ...
#
#
# Generation  32 / 64 ( 50 %)________________________________________________________
# 	Contamination  32 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  32 ...
#
#
# Generation  33 / 64 ( 51 %)________________________________________________________
# 	Contamination  33 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  33 ...
#
#
# Generation  34 / 64 ( 53 %)________________________________________________________
# 	Contamination  34 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  34 ...
#
#
# Generation  35 / 64 ( 54 %)________________________________________________________
# 	Contamination  35 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  35 ...
#
#
# Generation  36 / 64 ( 56 %)________________________________________________________
# 	Contamination  36 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  36 ...
#
#
# Generation  37 / 64 ( 57 %)________________________________________________________
# 	Contamination  37 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  37 ...
#
#
# Generation  38 / 64 ( 59 %)________________________________________________________
# 	Contamination  38 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  38 ...
#
#
# Generation  39 / 64 ( 60 %)________________________________________________________
# 	Contamination  39 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  39 ...
#
#
# Generation  40 / 64 ( 62 %)________________________________________________________
# 	Contamination  40 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  40 ...
#
#
# Generation  41 / 64 ( 64 %)________________________________________________________
# 	Contamination  41 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  41 ...
#
#
# Generation  42 / 64 ( 65 %)________________________________________________________
# 	Contamination  42 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  42 ...
#
#
# Generation  43 / 64 ( 67 %)________________________________________________________
# 	Contamination  43 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  43 ...
#
#
# Generation  44 / 64 ( 68 %)________________________________________________________
# 	Contamination  44 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  44 ...
#
#
# Generation  45 / 64 ( 70 %)________________________________________________________
# 	Contamination  45 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  45 ...
#
#
# Generation  46 / 64 ( 71 %)________________________________________________________
# 	Contamination  46 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  46 ...
#
#
# Generation  47 / 64 ( 73 %)________________________________________________________
# 	Contamination  47 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  47 ...
#
#
# Generation  48 / 64 ( 75 %)________________________________________________________
# 	Contamination  48 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  48 ...
#
#
# Generation  49 / 64 ( 76 %)________________________________________________________
# 	Contamination  49 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  49 ...
#
#
# Generation  50 / 64 ( 78 %)________________________________________________________
# 	Contamination  50 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  50 ...
#
#
# Generation  51 / 64 ( 79 %)________________________________________________________
# 	Contamination  51 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  51 ...
#
#
# Generation  52 / 64 ( 81 %)________________________________________________________
# 	Contamination  52 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  52 ...
#
#
# Generation  53 / 64 ( 82 %)________________________________________________________
# 	Contamination  53 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  53 ...
#
#
# Generation  54 / 64 ( 84 %)________________________________________________________
# 	Contamination  54 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  54 ...
#
#
# Generation  55 / 64 ( 85 %)________________________________________________________
# 	Contamination  55 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  55 ...
#
#
# Generation  56 / 64 ( 87 %)________________________________________________________
# 	Contamination  56 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  56 ...
#
#
# Generation  57 / 64 ( 89 %)________________________________________________________
# 	Contamination  57 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  57 ...
#
#
# Generation  58 / 64 ( 90 %)________________________________________________________
# 	Contamination  58 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  58 ...
#
#
# Generation  59 / 64 ( 92 %)________________________________________________________
# 	Contamination  59 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  59 ...
#
#
# Generation  60 / 64 ( 93 %)________________________________________________________
# 	Contamination  60 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  60 ...
#
#
# Generation  61 / 64 ( 95 %)________________________________________________________
# 	Contamination  61 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  61 ...
#
#
# Generation  62 / 64 ( 96 %)________________________________________________________
# 	Contamination  62 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  62 ...
#
#
# Generation  63 / 64 ( 98 %)________________________________________________________
# 	Contamination  63 ...
# 	pycatch22 : features extracted successfully___22 features
# 	Imputation  63 ...
#
#
# Initialization of the SHAP model with dimension (64, 22, 3)
# 	 SHAP_MODEL >> x_train shape: (38, 22)
# 	 SHAP_MODEL >> y_train shape: (38,)
# 	 SHAP_MODEL >> x_test shape: (26, 22)
# 	 SHAP_MODEL >> y_test shape: (26,)
#   0%|          | 0/26 [00:00<?, ?it/s]
#   0%|          | 0/38 [00:00<?, ?it/s]
# 	plot has been saved :  ./imputegap_assets/shap/eeg-alcohol_CDRec_pycatch_shap_all.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_grouped/eeg-alcohol_CDRec_pycatch_shap_reverse.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_grouped/eeg-alcohol_CDRec_pycatch_DTL_Waterfall.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_grouped/eeg-alcohol_CDRec_pycatch_DTL_Beeswarm.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_per_cat/eeg-alcohol_CDRec_pycatch_shap_geometry.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_per_cat/eeg-alcohol_CDRec_pycatch_shap_transformation.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_per_cat/eeg-alcohol_CDRec_pycatch_shap_correlation.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_per_cat/eeg-alcohol_CDRec_pycatch_shap_trend.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/eeg-alcohol_CDRec_pycatch_shap_cat.png
#
#
# 	plot has been saved :  ./imputegap_assets/shap/analysis_grouped/eeg-alcohol_CDRec_pycatch_shap_agg_reverse.png
#
#
# SHAP Explainer succeeded without fail, please find the results in : ./assets/shap/*
#
#
# > logs: shap explainer - Execution Time: 37.0441 seconds
#
#
#
# RMSE RESULTS (Y_TRAIN & Y_TEST): [0.45712812941363784, 0.5438438381672798, 0.26549016484114774, 0.6105707617030076, 0.30099782224277555, 0.2164511752833264, 0.4258210464001942, 0.49646942242787734, 0.29088160221281084, 0.42832279937048423, 0.32074277964658515, 0.4398059681001497, 0.47643304790654983, 0.4266036476868759, 0.32841220128853227, 0.5915170961060447, 0.4201599511374143, 0.5387023888018027, 0.7277953548636557, 0.36474897528179967, 0.38156484280457104, 0.40154479113393404, 0.21356345156822473, 0.22670635531640643, 0.38958088768583976, 0.41574772833042145, 0.3527871845087997, 0.42123833242103137, 0.3400310585076477, 0.4145000823792042, 0.450283153846639, 0.623345348422209, 0.648139380163163, 0.4504692040373999, 0.6510995213635289, 0.4112624109424558, 0.2734111041939645, 0.441893859674373, 0.4230430912231087, 0.5419989351751289, 0.43008671594070785, 0.4002232342192938, 0.3575246891539962, 0.3246621549210439, 0.3410004054178834, 0.3791815224363346, 0.4209640960064303, 0.3283571177822102, 0.37889306169318415, 0.3215640423792339, 0.2593775171700559, 0.36306603721774067, 0.516954076313444, 0.44337054947540194, 0.41789735854508175, 0.4686532112946319, 0.7322133872350807, 0.41646070834847226, 0.32855940447120274, 0.32650156399856983, 0.2560187082703063, 0.38756432910358035, 0.5420759853402481, 0.5406720225479795]
#
#
# Feature Importance:
# 	Feature : eeg-alcohol CDRec      with a score of 29.49      Geometry           Goodness of exponential fit to embedding distance distribution              CO_Embed2_Dist_tau_d_expfit_meandiff
#
# 	Feature : eeg-alcohol CDRec      with a score of 16.11      Transformation     Power in the lowest 20% of frequencies                                      SP_Summaries_welch_rect_area_5_1
#
# 	Feature : eeg-alcohol CDRec      with a score of 9.7        Geometry           10-bin histogram mode                                                       DN_HistogramMode_10
#
# 	Feature : eeg-alcohol CDRec      with a score of 8.14       Correlation        Histogram-based automutual information (lag 2, 5 bins)                      CO_HistogramAMI_even_2_5
#
# 	Feature : eeg-alcohol CDRec      with a score of 6.71       Geometry           Proportion of high incremental changes in the series                        MD_hrv_classic_pnn40
#
# 	Feature : eeg-alcohol CDRec      with a score of 6.44       Geometry           5-bin histogram mode                                                        DN_HistogramMode_5
#
# 	Feature : eeg-alcohol CDRec      with a score of 5.32       Correlation        First 1/e crossing of the ACF                                               CO_f1ecac
#
# 	Feature : eeg-alcohol CDRec      with a score of 4.78       Correlation        Time reversibility                                                          CO_trev_1_num
#
# 	Feature : eeg-alcohol CDRec      with a score of 4.01       Geometry           Transition matrix column variance                                           SB_TransitionMatrix_3ac_sumdiagcov
#
# 	Feature : eeg-alcohol CDRec      with a score of 3.91       Trend              Error of 3-point rolling mean forecast                                      FC_LocalSimple_mean3_stderr
#
# 	Feature : eeg-alcohol CDRec      with a score of 2.85       Trend              Entropy of successive pairs in symbolized series                            SB_MotifThree_quantile_hh
#
# 	Feature : eeg-alcohol CDRec      with a score of 1.29       Geometry           Positive outlier timing                                                     DN_OutlierInclude_p_001_mdrmd
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.66       Transformation     Centroid frequency                                                          SP_Summaries_welch_rect_centroid
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.4        Geometry           Rescaled range fluctuation analysis (low-scale scaling)                     SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.14       Correlation        Change in autocorrelation timescale after incremental differencing          FC_LocalSimple_mean1_tauresrat
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.04       Geometry           Negative outlier timing                                                     DN_OutlierInclude_n_001_mdrmd
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Correlation        First minimum of the ACF                                                    CO_FirstMin_ac
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Geometry           Longest stretch of above-mean values                                        SB_BinaryStats_mean_longstretch1
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Trend              Wangs periodicity metric                                                    PD_PeriodicityWang_th0_01
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Correlation        First minimum of the AMI function                                           IN_AutoMutualInfoStats_40_gaussian_fmmi
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Geometry           Longest stretch of decreasing values                                        SB_BinaryStats_diff_longstretch0
#
# 	Feature : eeg-alcohol CDRec      with a score of 0.0        Geometry           Detrended fluctuation analysis (low-scale scaling)                          SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1

# %% [markdown]
# All features extractors developed in ImputeGAP are available in the **ts.extractors module**, which can be listed as follows:

# %%
ts.extractors
# Out:
# ['pycatch', 'tsfel', 'tsfresh']
